# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdurrasyiid/PDS1441/blob/master/EDA_dan_Cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Eksplorasi Data Analysis**

# %%
import pandas as pd

# %%
dataset1 = pd.read_csv("iris_train.csv") #tipenya adalah data frame

# %%
dataset1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.1          3.4           1.5          0.2      Iris-setosa
# 1             6.3          2.5           5.0          1.9   Iris-virginica
# 2             5.9          3.0           4.2          1.5  Iris-versicolor
# 3             5.7          2.6           3.5          1.0  Iris-versicolor
# 4             7.7          2.8           6.7          2.0   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 100           5.4          3.4           1.7          0.2      Iris-setosa
# 101           5.6          2.5           3.9          1.1  Iris-versicolor
# 102           6.4          2.9           4.3          1.3  Iris-versicolor
# 103           7.9          3.8           6.4          2.0   Iris-virginica
# 104           5.4          3.0           4.5          1.5  Iris-versicolor
#
# [105 rows x 5 columns]

# %%
dataset1.describe() #deskripsi statistika basic
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    105.000000   105.000000    105.000000   105.000000
# mean       5.918095     3.042857      3.908571     1.249524
# std        0.781613     0.437839      1.705935     0.736170
# min        4.600000     2.000000      1.000000     0.100000
# 25%        5.200000     2.800000      1.700000     0.400000
# 50%        5.800000     3.000000      4.400000     1.400000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.200000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dataset1["sepal_length"], dataset1["petal_length"], "o")
plt.show()

# %% [markdown]
# ## **Cleansing**

# %%
dataset1.loc[dataset1["species"]=="Iris-setosa","species"] = 0
dataset1.loc[dataset1["species"]=="Iris-virginica","species"] = 1
dataset1.loc[dataset1["species"]=="Iris-versicolor","species"] = 2

# %%
dataset1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.4           1.5          0.2       0
# 1             6.3          2.5           5.0          1.9       1
# 2             5.9          3.0           4.2          1.5       2
# 3             5.7          2.6           3.5          1.0       2
# 4             7.7          2.8           6.7          2.0       1
# ..            ...          ...           ...          ...     ...
# 100           5.4          3.4           1.7          0.2       0
# 101           5.6          2.5           3.9          1.1       2
# 102           6.4          2.9           4.3          1.3       2
# 103           7.9          3.8           6.4          2.0       1
# 104           5.4          3.0           4.5          1.5       2
#
# [105 rows x 5 columns]

# %%
dataset1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     species
# count    105.000000   105.000000    105.000000   105.000000  105.000000
# mean       5.918095     3.042857      3.908571     1.249524    1.104762
# std        0.781613     0.437839      1.705935     0.736170    0.819519
# min        4.600000     2.000000      1.000000     0.100000    0.000000
# 25%        5.200000     2.800000      1.700000     0.400000    0.000000
# 50%        5.800000     3.000000      4.400000     1.400000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.200000      6.900000     2.500000    2.000000

# %%
dataset1["species"]=dataset1["species"].astype(float)

# %%
dataset1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.4           1.5          0.2      0.0
# 1             6.3          2.5           5.0          1.9      1.0
# 2             5.9          3.0           4.2          1.5      2.0
# 3             5.7          2.6           3.5          1.0      2.0
# 4             7.7          2.8           6.7          2.0      1.0
# ..            ...          ...           ...          ...      ...
# 100           5.4          3.4           1.7          0.2      0.0
# 101           5.6          2.5           3.9          1.1      2.0
# 102           6.4          2.9           4.3          1.3      2.0
# 103           7.9          3.8           6.4          2.0      1.0
# 104           5.4          3.0           4.5          1.5      2.0
#
# [105 rows x 5 columns]

# %%
plt.plot(dataset1["sepal_length"], dataset1["petal_length"], "o")
plt.show()

# %%
dataset2= pd.read_csv("SampleData.csv")

# %%
dataset2
# Out:
#    HouseID    Area  CityCenter Owner  Nrooms District Color    Price
# 0      T20   99.41         961     M       3        D     G   817.21
# 1       T9  104.35         947     D       1        C     T   436.46
# 2       T8  146.18         923     M       1        A     G   683.77
# 3      T12   83.00         919     M       6        B     T  1246.79
# 4      T18  173.76         765     D       3        A     G   899.88
# 5      T13  123.68         741     D       1        A     T   581.17
# 6       T5  126.90         720     D       2        D     G   785.88
# 7      T10  193.24         716     D       3        D     G  1197.97
# 8      T19  192.86         612     M       4        C     T   942.04
# 9      T11  209.98         610     M       3        A     T  1274.70
# 10      T3  179.32         600     M       2        A     G   847.64
# 11      T1  230.03         539     D       6        A     G  1359.76
# 12     T16  199.34         499     D       5        A     G  1424.32
# ...

# %%
plt.plot(dataset2["Area"], dataset2["Price"], "o")
